# %%
#pH dependent opioid biosensor activation
#Jan 2020 Will Cheney
#Generates scatter plot for pH data
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind_from_stats

# %%
phdata = [5.1, 6.1, 7, 8.1] #x data
null_mean = [17409.54, 21517.42, 9899.55, 4480.31] #y data
morphine_mean = [18591.69, 29906.22, 27142.03, 26206.08]
damgo_mean = [23461.38, 90276.86, 171166.70, 145653.97]
enkephalin_mean = [24955.02, 57502.93, 82330.68, 68248.14]
endomorphin_mean = [18415.60, 43678.96, 78474.04, 60343.09]
endomorphin2_mean = [13712.64, 30266.83, 38188.67, 43456.96]



null_error = [557.3153011, 198.2401346, 262.511315, 198.8519119]
morphine_error = [1066.499761, 1290.728533, 1305.257196, 1787.331945]
damgo_error = [1720.037304, 3263.211188, 10416.68562, 13213.83758]
enkephalin_error = [753.9479167, 4643.493984, 2499.307239, 514.5413817]
endomorphin_error = [1665.273573, 2726.91035, 4262.978763, 1334.793526]
endomorphin2_error = [1523.641366, 3537.051149, 3117.169943, 4758.194605]



null_median = [4001.83, 4933.50, 1839.33, 1287.00]
morphine_median = [4229.00, 10427.17, 7017.50, 6060.67]
damgo_median = [5975.67, 49425.00, 128641.67, 80364.67]
enkephalin_median = [5749.17, 14089.83, 29658.67, 25859.33]
endomorphin_median = [4132.50, 9681.67, 28899.00, 23265.00]
endomorphin2_median = [3464.00, 5510.00, 10358.83, 14619.17]
                       
                       
null_median_error = [27.75588026, 126.7129301, 9.56846673, 27.76088375]
morphine_median_error = [261.0258608, 380.8294311, 304.6317449, 509.8819035]
damgo_median_error = [444.9541799, 3786.915918, 10582.11559, 14477.32907]
enkephalin_median_error = [174.7103953, 3216.376878, 1647.009074, 967.6521701]
endomorphin_median_error =[330.8824061, 841.9196649, 2655.654094, 496.3191178]
endomorphin2_median_error =[334.7394509, 786.172161, 1143.875746, 2156.559464]

# %%
###MEAN Figure

plt.scatter(phdata, damgo_mean, label = 'DAMGO', marker = 'v')
plt.errorbar(phdata, damgo_mean, yerr = damgo_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, damgo_mean, linestyle = 'dashed')


plt.scatter(phdata, morphine_mean, label = 'Morphine', marker = 's')
plt.errorbar(phdata, morphine_mean, yerr = morphine_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, morphine_mean, linestyle = 'dashed')



plt.scatter(phdata, enkephalin_mean, label = 'Enkephalin', marker = 'd')
plt.errorbar(phdata, enkephalin_mean, yerr = enkephalin_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, enkephalin_mean, linestyle = 'dashed')



plt.scatter(phdata, endomorphin_mean, label = 'Endomorphin-I', marker = '*')
plt.errorbar(phdata, endomorphin_mean, yerr = endomorphin_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, endomorphin_mean, linestyle = 'dashed')


plt.scatter(phdata, endomorphin2_mean, label = 'Endomorphin-II', marker = '>')
plt.errorbar(phdata, endomorphin2_mean, yerr = endomorphin2_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, endomorphin2_mean, linestyle = 'dashed')


plt.scatter(phdata, null_mean, label = 'H2O', color = 'slategrey')
plt.errorbar(phdata, null_mean, yerr = null_error, linestyle = 'none', color = 'black', capsize = 2, elinewidth = 1, zorder = 10)
plt.plot(phdata, null_mean, linestyle = 'dashed', color = 'slategrey')


plt.legend()
fig = plt.gcf()
plt.show()

# %%
fig.savefig('2020-02-24 pH variation all ligands mean FI',dpi = 300, bbox_inches='tight')
